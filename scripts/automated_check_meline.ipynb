# %%
import pandas as pd

df = pd.read_excel("HAM.xlsx")     # first sheet by default

df = df.astype({
    'Site': 'category',
    'SubjectStatus': 'category',
    'Visit': 'category',
    'VarGroup1Row': 'category',
    'HAMTEST': 'category',
})

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3332 entries, 0 to 3331
# Data columns (total 15 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   SubjectID           3332 non-null   object
#  1   Site                3332 non-null   category
#  2   SubjectStatus       3332 non-null   category
#  3   Visit               3332 non-null   category
#  4   Form                3332 non-null   object
#  5   FormEntryDate       0 non-null      float64
#  6   HAMPERF             3332 non-null   object
#  7   HAMREASND           0 non-null      float64
#  8   HAMDAT              3332 non-null   datetime64[ns]
#  9   HAMTIM              3332 non-null   object
#  10  VarGroup1Row        3332 non-null   category
#  11  HAMTEST             3332 non-null   category
#  12  HAMORRES1           3332 non-null   int64
#  13  HAMORRES2           3332 non-null   int64
#  14  SubjectVisitFormID  3332 non-null   int64
# ...
